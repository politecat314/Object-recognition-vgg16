# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
import os

# %% [markdown]
# ## impot vgg16 model

# %%
model = VGG16()
print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 82s 0us/step
# 553476096/553467096 [==============================] - 82s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## import the images

# %%
root = 'Images'
image_names = os.listdir(root)
# image_names

# %%
exterior = 'categories/exterior'
interior = 'categories/interior'

car_classes = ['minivan','convertible','sports_car','police_van','minibus','jeep','cab','ambulance','limousine']

# %%
for name in image_names:
    # load the image
    image = load_img(root+'/'+name, target_size=(224, 224))
    
    # convert the image pixels to a numpy array
    image = img_to_array(image)
    
    # reshape single image for model
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    
    # preprocess the image for the VGG model
    image = preprocess_input(image)
    
    # predict the probability across all output classes
    yhat = model.predict(image)
    
    # convert the probabilities to class labels
    label = decode_predictions(yhat)
    
    # retrieve the most likely result, e.g. highest probability
    label = label[0][0]
    
    if label[1] not in car_classes: # is not exterior of a car
        # print the classification
        print(name)
        print('%s (%.2f%%)' % (label[1], label[2]*100))
        print()
        os.replace(root+'/'+name, interior+'/'+name)
    else: # is exterior of a car
        os.replace(root+'/'+name, exterior+'/'+name)
# Out:
# 0-02-03-000728a988f4d2178f840349caf77e4fbf72a66811d0c00243c46d0ccdb7db33_b1dd4628.jpg
# seat_belt (22.43%)
#
# 0-02-03-5c26c4cd5003cf274c1cf70d433c7cb2757076ac1c97caa2e0cdd143892d097f_69afbe38.jpg
# seat_belt (45.95%)
#
# 0-02-03-f0b7d665958c46eb7700d8db443ac72286a487c80a8f3a874f550707070d189b_34ca53fc.jpg
# stretcher (11.82%)
#
# 0-02-03-f5d68cb34fe6f706d4c48379a78222206fb35169e3f643f50714b3d2b4da3b66_375c921d.jpg
# limousine (71.93%)
#
# 0-02-03-fffd1ad84836f48bf7723a7be9a36776c846c080046d54519641cd3c28bb68df_7f34b62b.jpg
# limousine (39.32%)
#
# 0-02-06-040a11b4d0412fe98d3d737ac83bc56c8351f58ba99708bdf7e2b2292257026f_f3692030.jpg
# racer (63.01%)
#
# 0-02-06-1a093a1999048b35f67445652dff7ec32f7e24ee49b11389cb2ae5746966b4a8_c5ac2236.jpg
# ashcan (30.47%)
#
# 0-02-06-1a5584c9a12f299e142855224709b9ecc6a1cdcb98bf60ba5609f5876920f372_f4daee48.jpg
# motor_scooter (62.23%)
#
# 0-02-06-2249fda490fbbec143f5fc85cd4d20f63eb9492f28d0d8b793f4cce0f9ba2971_217095c7.jpg
# CD_player (12.86%)
#
# 0-02-06-315f974d1c42279aa5350b7146057638133bdb5505b9346642687fe440ef2c0e_a0bc3206.jpg
# padlock (20.12%)
#
# 0-02-06-4124a82d00753c3d0f6b1ca7ed8adf95933e4f4d29500ac317404ab2724e99ac_568ae159.jpg
# vacuum (14.59%)
#
# 0-02-06-441a9c51d80ea97ad956062d4c84ce4e0fb4e0ce4d8802a0dec993ffcb4d47dd_ceec5e86.jpg
# seat_belt (80.06%)
#
# 0-02-06-4434e585cca2a3c00fcaebfc6f7b4cb0364a9d8789e3c6f70fad3fc93d372bcb_723f991a.jpg
# motor_scooter (15.75%)
#
# 0-02-06-56900eaa6e0f620c6b00571eb52c337dfe2d410c59c7030ea8f625bd407ec9dc_fe51f10b.jpg
# 0-02-08-5be49a9d01e9db6530c74ab8c4fd90d71140b2d692b0930699e7d7420a4cd449_1345c71c.jpg
# golfcart (36.76%)
#
# 0-02-08-ee7f58073ef24d89ad9bedfb5340a301b508d2b889130dfaf64f854185e0f13e_1019ca54.jpg
# car_wheel (10.93%)
#
# 0-02-08-ff5273407b1832ed025bb04996262bb5a62bfc339c90de560d3f65f5f2da3195_856b5e95.jpg
# motor_scooter (23.07%)
#
# 04.jpg
# motor_scooter (15.19%)
#
# 1 (1).jpg
# recreational_vehicle (28.84%)
#
# 1.jpg
# recreational_vehicle (28.84%)
#
# 10.jpg
# gasmask (17.79%)
#
# 2020-12-03 18.55.52.jpg
# limousine (53.33%)
#
# 4.jpg
# grille (44.83%)
#
# 5.jpg
# bell_cote (17.13%)
#
# 79321211_493362377934811_2626064217341427712_n.jpg
# limousine (36.20%)
#
# 8.jpg
# motor_scooter (32.58%)
#
# Capture - 2.PNG
# tow_truck (11.74%)
#
# car 3.jpg
# motor_scooter (27.94%)
#
# dd5b7cd4-b419-4312-9b59-83f5f0ba3da4.jpg
# amphibian (24.56%)
#
# File 1.jpg
# chain_saw (37.70%)
#
# File 2.jpg
# chain_saw (46.39%)
#
# File 3.jpg
# chain_saw (31.79%)
#
# File 4.jpg
# chain_saw (26.01%)
#
# File 5.jpg
# pay-phone (55.59%)
#
# File 6.jpg
# pay-phone (79.00%)
#
# IMG-6360.JPG
# ashcan (13.85%)
#
# IMG-6363.JPG
# parking_meter (21.47%)
#
# IMG-6369.JPG
# car_mirror (58.00%)
#
# IMG-6371.JPG
# car_mirror (42.23%)
#
# IMG-6373.JPG
# disk_brake (12.84%)
#
# IMG-6374.JPG
# running_shoe (20.39%)
#
# IMG-6375.JPG
# binoculars (81.22%)
#
# IMG-6376.JPG
# odometer (46.93%)
#
# IMG-8f968be462bd074a6bc985bca6e3319e-V.jpg
# limousine (20.47%)
#
# IMG-a6cc1bc50d0c6fd333a3d200e40ebf1e-V.jpg
# recreational_vehicle (54.24%)
#
# IMG-b993d65bb29999043dba2f7e69f0dd01-V.JPG
# oil_filter (57.43%)
#
# IMG-c687c6f51f0962e050ac794de39ac4e0-V.jpg
# recreational_vehicle (24.01%)
#
# IMG-e264ab13d9f7300fe1b648cee3de6da1-V.JPG
# toilet_seat (30.22%)
#
# IMG-f3817eee4cab3068c9549d16f9e736a5-V.jpg
# limousine (33.46%)
#
# IMG_0370.jpg
# seat_belt (46.15%)
#
# IMG_1477.JPG
# chain_saw (49.06%)
#
# IMG_1479.JPG
# racer (21.93%)
#
# IMG_1483.JPG
# seat_belt (82.73%)
#
# IMG_1485.JPG
# sewing_machine (7.09%)
#
# IMG_1491.JPG
# crash_helmet (34.39%)
#
# IMG_1492.JPG
# ashcan (18.61%)
#
# IMG_1496.JPG
# snowmobile (16.25%)
#
# IMG_1500.JPG
# parking_meter (9.01%)
#
# IMG_1505.JPG
# seat_belt (94.64%)
#
# IMG_1509.JPG
# crash_helmet (70.43%)
#
# IMG_1546.jpeg
# vacuum (76.22%)
#
# IMG_1547.jpeg
# snowmobile (58.88%)
#
# IMG_1549 (1).jpeg
# limousine (79.41%)
#
# IMG_1549.jpeg
# limousine (79.41%)
#
# IMG_2985.jpg
# golfcart (9.62%)
#
# IMG_4241.jpg
# bobsled (49.39%)
#
# IMG_4245.jpg
# golfcart (33.92%)
#
# IMG_4246.jpg
# snowmobile (48.80%)
#
# IMG_4247.jpg
# garbage_truck (8.41%)
#
# IMG_4519.jpg
# racer (29.25%)
#
# IMG_4521.jpg
# bullet_train (90.19%)
#
# IMG_4522.jpg
# car_mirror (40.44%)
#
# IMG_4523.jpg
# limousine (13.94%)
#
# IMG_4524.jpg
# car_wheel (27.81%)
#
# MicrosoftTeams-image (20).png
# snowmobile (19.54%)
#
# MicrosoftTeams-image (3).png
# beach_wagon (51.58%)
#
# Photo 1.jpg
# speedboat (44.01%)
#
# Photo 2.jpg
# golfcart (45.10%)
#
# Photo 3.jpg
# golfcart (33.68%)
#
# photo_2021-02-01_13-19-14 (3).jpg
# beach_wagon (47.05%)
#
# photo_2021-02-01_13-19-14 (5).jpg
# cannon (15.66%)
#
# pic.jpg
# vacuum (22.69%)
#
# Pic1 P3549.jpg
# motor_scooter (18.19%)
#
# Pic2 P3549.jpg
# sandal (12.90%)
#
# Picture 1.jpg
# ashcan (44.56%)
#
# Picture 2.jpg
# seat_belt (69.81%)
#
# Picture 3.jpg
# sandal (30.63%)
#
# viber image10.jpg
# disk_brake (54.29%)
#
# viber image5.jpg
# racer (10.92%)
#
# viber image6.jpg
# Model_T (26.56%)
#
# viber image7.jpg
# limousine (23.46%)
#
# viber_image_2019-08-07_12-14-01.jpg
# amphibian (64.51%)
#
# viber_image_2019-08-07_12-15-19.jpg
# oxygen_mask (41.73%)
#
# viber_image_2019-09-02_09-07-18.jpg
# racer (43.28%)
#
# viber_image_2019-09-02_09-07-24.jpg
# snowmobile (18.28%)
#
# viber_image_2019-11-05_11-28-53.jpg
# motor_scooter (62.21%)
#
# viber_image_2019-11-05_11-28-54.jpg
# motor_scooter (56.00%)
#
# viber_image_2019-11-13_10-59-04.jpg
# snowplow (21.47%)
#
# viber_image_2019-11-13_10-59-08.jpg
# tank (24.29%)
#
# viber_image_2019-11-13_10-59-14.jpg
# odometer (52.61%)
#
# viber_image_2019-11-13_10-59-15.jpg
# car_mirror (40.12%)
#
# viber_image_2019-11-13_10-59-17.jpg
# parking_meter (14.93%)
#
# viber_image_2021-02-22_11-13-02.jpg
# motor_scooter (40.57%)
#
# viber_image_2021-02-22_11-13-04.jpg
# seat_belt (59.33%)
#
# viber_image_2021-02-22_11-13-06.jpg
# seat_belt (56.15%)
#
# viber_image_2021-02-22_11-13-07.jpg
# snowplow (21.86%)
#
# viber_image_2021-03-03_11-42-33.jpg
# motor_scooter (39.15%)
#
# viber_image_2021-03-03_11-42-55.jpg
# snowmobile (28.75%)
#
# viber_image_2021-03-03_11-46-27.jpg
# snowplow (17.46%)
#
# WhatsApp Image 2021-03-11 at 10.12.50 (4).jpeg
# recreational_vehicle (11.43%)
#
# WhatsApp Image 2021-08-01 at 11.14.38 AM.JPEG
# iron (11.63%)
#
# WhatsApp Image 2021-08-01 at 11.14.44 AM.JPEG
# breakwater (14.19%)
